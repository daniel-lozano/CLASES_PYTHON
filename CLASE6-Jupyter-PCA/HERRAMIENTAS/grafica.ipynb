# %%
# %pylab inline
import module_practice as mp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=linspace(-2*pi,2*pi,1000)

# %%
for i in range(1,5):
    y=sin(x*i)
    plot(x,y,label=str(i))
plt.grid()
plt.legend()

# %%
y=mp.poli3(x,1,-1,-1,1)
plot(x,y)
plt.grid()

# %%
a=mp.mayor(11,12)
print(a)
# Out:
# 12
